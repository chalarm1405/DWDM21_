# %% [markdown]
# <a href="https://colab.research.google.com/github/chalarm1405/DWDM21_/blob/main/test_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
path = '/content/drive/My Drive/test' #ชื่อ path ชี้ไปไฟล์ที่เราต้องการ
data_01 = pd.read_csv(os.path.join(path,'1.csv'))
data_01
# Out:
#            Store  Member No. Billing Date        Ticket Number  รหัสสินค้า  \
# 0       S002-RTB   NonMember     1/1/2023  S002230101000119392     1145528
# 1       S002-RTB   NonMember     1/1/2023  S002230101005039881     1118291
# 2       S002-RTB   NonMember     1/1/2023  S002230101005039881     1077454
# 3       S002-RTB   NonMember     1/1/2023  S002230101005039881      291538
# 4       S002-RTB   NonMember     1/1/2023  S002230101005039881     1119482
# ...          ...         ...          ...                  ...         ...
# 228550  S020-HYI   NonMember   26/11/2022  S020221126005145272     1160172
# 228551  S020-HYI  1004771131   26/12/2022  S020221226003051813      241545
# 228552  S020-HYI  1004771131   26/11/2022  S020221126005145145     1144580
# 228553  S020-HYI  1004771131   26/11/2022  S020221126005145145     1084136
# 228554  S020-HYI  1004771131   27/11/2022  S020221127005145372     1104248
#
# ...

# %%
path = '/content/drive/My Drive/test' #ชื่อ path ชี้ไปไฟล์ที่เราต้องการ
data_02 = pd.read_csv(os.path.join(path,'2.csv'))
data_02
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         รหัสสินค้า                               ชื่อสินค้า Base Unit  \
# 0           161101                    ค.ดีวีดี MAR MRZ9001P        EA
# 1           161620                     ค.ดีวีดี MAR DV-4300        EA
# 2           188436         ค.บันทึกดีวีดี PANA DMR-E500HGCS        EA
# 3           203250               ค.ดีวีดี ACO AN-VEITADVD50        EA
# 4           207750         ค.บันทึกดีวีดี PANA DMR-EH60GCSS        EA
# ...            ...                                      ...       ...
# 271322     1225730  คิวเอ็นอีดีทีวี 75"  LG 75QNED80SQA.ATM        EA
# 271323     1225856      โอแอลอีดีทีวี 55" SAM QA55S95BAKXXT        EA
# 271324     1225864      โอแอลอีดีทีวี 65" SAM QA65S95BAKXXT        EA
# ...

# %%
path = '/content/drive/My Drive/test' #ชื่อ path ชี้ไปไฟล์ที่เราต้องการ
data_03 = pd.read_csv(os.path.join(path,'3.1.csv'))
data_03
# Out:
#      Customer No.                 ประเภทธุรกิจหลัก  \
# 0           76214  10.หน่วยงานราชการ/สถานศึกษา/วัด
# 1          195568                           3.ช่าง
# 2          644880           11.ร้านค้าช่วง/นายหน้า
# 3         8115701              12.End User/ลูกบ้าน
# 4        10000122                1.ออฟฟิศ/สำนักงาน
# ...           ...                              ...
# 7301        k5552               9.โรงงานอุตสาหกรรม
# 7302    KJ0610210           11.ร้านค้าช่วง/นายหน้า
# 7303     L4760288              5.ธุรกิจที่พักอาศัย
# 7304     TI146109             6.โรงแรม/รีสอร์ท/สปา
# 7305          NaN                              NaN
#
#                   ประเภทธุรกิจย่อย Cust_type code size
# 0            3.วัด/สถานปฏิบัติธรรม       B2B         M
# 1                         3.ช่างไฟ       B2B         S
# 2         1.ร้านค้าปลีก/ร้านค้าส่ง       B2B        SS
# 3           3.ลูกบ้าน โครงการคอนโด       B2B        SS
# 4                 1.สำนักงานทั่วไป       B2B         S
# ...

# %%
path = '/content/drive/My Drive/test' #ชื่อ path ชี้ไปไฟล์ที่เราต้องการ
data_04 = pd.read_csv(os.path.join(path,'4.csv'))
data_04
# Out:
#        Store  Site Site_Desc                 TH_NAME เขตรับผิดชอบ Region  \
# 0   S002-RTB  S002       RTB            รัตนาธิเบศร์          DM4    BKK
# 1   S006-PDP  S006       PDP          พาราไดซ์ พาร์ค         DM15    BKK
# 2   S009-RCD  S009       RCD              รัชดาภิเษก          DM3    BKK
# 3   S010-PCT  S010       PCT                เพลินจิต         DM20    BKK
# 4   S011-PKT  S011       PKT                  ภูเก็ต          DM5      S
# 5   S012-CMI  S012       CMI               เชียงใหม่          DM6      N
# 6   S013-RKH  S013       RKH                รามคำแหง         DM12    BKK
# 7   S014-RMA  S014       RMA                พระราม 2          DM4    BKK
# 8   S015-PCC  S015       PCC            สำนักงานใหญ่         DM18    BKK
# 9   S016-LPO  S016       LPO                ลาดพร้าว         DM19    BKK
# 10  S017-RIT  S017       RIT        เอกมัย-รามอินทรา         DM12    BKK
# 11  S018-PTY  S018       PTY                   พัทยา         DM10      E
# ...

# %% [markdown]
# #เช็คค่า missing

# %%
data_01.isnull()
# Out:
#         Store  Member No.  Billing Date  Ticket Number  รหัสสินค้า  \
# 0       False       False         False          False       False
# 1       False       False         False          False       False
# 2       False       False         False          False       False
# 3       False       False         False          False       False
# 4       False       False         False          False       False
# ...       ...         ...           ...            ...         ...
# 228550  False       False         False          False       False
# 228551  False       False         False          False       False
# 228552  False       False         False          False       False
# 228553  False       False         False          False       False
# 228554  False       False         False          False       False
#
#         ชื่อสินค้า  Billing Quantity.Base Unit  Billing Amount (+VAT)
# 0            False                       False                  False
# ...

# %%
data_02.isnull()
# Out:
#         รหัสสินค้า  ชื่อสินค้า  Base Unit  กลุ่มสินค้าหลัก  ชื่อกลุ่มสินค้า  \
# 0            False       False      False            False            False
# 1            False       False      False            False            False
# 2            False       False      False            False            False
# 3            False       False      False            False            False
# 4            False       False      False            False            False
# ...            ...         ...        ...              ...              ...
# 271322       False       False      False            False            False
# 271323       False       False      False            False            False
# 271324       False       False      False            False            False
# 271325       False       False      False            False            False
# 271326       False       False      False            False            False
#
# ...

# %%
data_03.isnull()
# Out:
#       Customer No.  ประเภทธุรกิจหลัก  ประเภทธุรกิจย่อย  Cust_type  code size
# 0            False             False             False      False      False
# 1            False             False             False      False      False
# 2            False             False             False      False      False
# 3            False             False             False      False      False
# 4            False             False             False      False      False
# ...            ...               ...               ...        ...        ...
# 7301         False             False             False      False      False
# 7302         False             False             False      False      False
# 7303         False             False             False      False      False
# 7304         False             False             False      False      False
# 7305          True              True              True       True       True
#
# [7306 rows x 5 columns]

# %%
data_04.isnull()
# Out:
#     Store   Site  Site_Desc  TH_NAME  เขตรับผิดชอบ  Region   Zone  Province  \
# 0   False  False      False    False         False   False  False     False
# 1   False  False      False    False         False   False  False     False
# 2   False  False      False    False         False   False  False     False
# 3   False  False      False    False         False   False  False     False
# 4   False  False      False    False         False   False  False     False
# 5   False  False      False    False         False   False  False     False
# 6   False  False      False    False         False   False  False     False
# 7   False  False      False    False         False   False  False     False
# 8   False  False      False    False         False   False  False     False
# 9   False  False      False    False         False   False  False     False
# 10  False  False      False    False         False   False  False     False
# ...

# %%
data_01.isnull().any()
# Out:
# Store                         False
# Member No.                    False
# Billing Date                  False
# Ticket Number                 False
# รหัสสินค้า                    False
# ชื่อสินค้า                    False
# Billing Quantity.Base Unit    False
# Billing Amount (+VAT)         False
# dtype: bool

# %%
data_02.isnull().any()
# Out:
# รหัสสินค้า           False
# ชื่อสินค้า           False
# Base Unit            False
# กลุ่มสินค้าหลัก      False
# ชื่อกลุ่มสินค้า      False
# กลุ่มสินค้า1         False
# กลุ่มสินค้า1_Desc    False
# กลุ่มสินค้า2         False
# กลุ่มสินค้า2_Desc    False
# กลุ่มสินค้า3         False
# กลุ่มสินค้า3_Desc    False
# Vendor               False
# Vendor_Name          False
# Brand                 True
# dtype: bool

# %%
data_02 = data_02.dropna()
data_02
# Out:
#         รหัสสินค้า                               ชื่อสินค้า Base Unit  \
# 0           161101                    ค.ดีวีดี MAR MRZ9001P        EA
# 1           161620                     ค.ดีวีดี MAR DV-4300        EA
# 2           188436         ค.บันทึกดีวีดี PANA DMR-E500HGCS        EA
# 3           203250               ค.ดีวีดี ACO AN-VEITADVD50        EA
# 4           207750         ค.บันทึกดีวีดี PANA DMR-EH60GCSS        EA
# ...            ...                                      ...       ...
# 271322     1225730  คิวเอ็นอีดีทีวี 75"  LG 75QNED80SQA.ATM        EA
# 271323     1225856      โอแอลอีดีทีวี 55" SAM QA55S95BAKXXT        EA
# 271324     1225864      โอแอลอีดีทีวี 65" SAM QA65S95BAKXXT        EA
# 271325     1227489  โอแอลอีดีทีวี POSE 42" LG 42LX1QPSA.ATM        EA
# 271326     1227525  โอแอลอีดีทีวี POSE 55" LG 55LX1QPSA.ATM        EA
#
#        กลุ่มสินค้าหลัก ชื่อกลุ่มสินค้า กลุ่มสินค้า1      กลุ่มสินค้า1_Desc  \
# ...

# %%
before = 271327
after = 271318
print(f'before = {before} \nafter = {after}\nwhich is {100*((before-after)/before)}')
# Out:
# before = 271327
# after = 271318
# which is 0.003317030741503794

# %%
data_03.isnull().any()
# Out:
# Customer No.        True
# ประเภทธุรกิจหลัก    True
# ประเภทธุรกิจย่อย    True
# Cust_type           True
# code size           True
# dtype: bool

# %%
data_03 = data_03.dropna()
data_03
# Out:
#      Customer No.                 ประเภทธุรกิจหลัก  \
# 0           76214  10.หน่วยงานราชการ/สถานศึกษา/วัด
# 1          195568                           3.ช่าง
# 2          644880           11.ร้านค้าช่วง/นายหน้า
# 3         8115701              12.End User/ลูกบ้าน
# 4        10000122                1.ออฟฟิศ/สำนักงาน
# ...           ...                              ...
# 7300     H8413033               9.โรงงานอุตสาหกรรม
# 7301        k5552               9.โรงงานอุตสาหกรรม
# 7302    KJ0610210           11.ร้านค้าช่วง/นายหน้า
# 7303     L4760288              5.ธุรกิจที่พักอาศัย
# 7304     TI146109             6.โรงแรม/รีสอร์ท/สปา
#
#                   ประเภทธุรกิจย่อย Cust_type code size
# 0            3.วัด/สถานปฏิบัติธรรม       B2B         M
# 1                         3.ช่างไฟ       B2B         S
# 2         1.ร้านค้าปลีก/ร้านค้าส่ง       B2B        SS
# 3           3.ลูกบ้าน โครงการคอนโด       B2B        SS
# 4                 1.สำนักงานทั่วไป       B2B         S
# ...

# %%
before = 7306
after = 7305
print(f'before = {before} \nafter = {after}\nwhich is {100*((before-after)/before)}')
# Out:
# before = 7306
# after = 7305
# which is 0.013687380235422939

# %%
data_04.isnull().any()
# Out:
# Store           False
# Site            False
# Site_Desc       False
# TH_NAME         False
# เขตรับผิดชอบ    False
# Region          False
# Zone            False
# Province        False
# Size Store      False
# dtype: bool

# %% [markdown]
# #รวมตาราง

# %%
data = data_01.merge(data_02,how='left',left_on='รหัสสินค้า',right_on='รหัสสินค้า')   
data
# Out:
#            Store  Member No. Billing Date        Ticket Number  รหัสสินค้า  \
# 0       S002-RTB   NonMember     1/1/2023  S002230101000119392     1145528
# 1       S002-RTB   NonMember     1/1/2023  S002230101005039881     1118291
# 2       S002-RTB   NonMember     1/1/2023  S002230101005039881     1077454
# 3       S002-RTB   NonMember     1/1/2023  S002230101005039881      291538
# 4       S002-RTB   NonMember     1/1/2023  S002230101005039881     1119482
# ...          ...         ...          ...                  ...         ...
# 228550  S020-HYI   NonMember   26/11/2022  S020221126005145272     1160172
# 228551  S020-HYI  1004771131   26/12/2022  S020221226003051813      241545
# 228552  S020-HYI  1004771131   26/11/2022  S020221126005145145     1144580
# 228553  S020-HYI  1004771131   26/11/2022  S020221126005145145     1084136
# 228554  S020-HYI  1004771131   27/11/2022  S020221127005145372     1104248
#
# ...

# %%
data_x = data.merge(data_04,how='left',left_on='Store',right_on='Store')   
data_x
# Out:
#            Store  Member No. Billing Date        Ticket Number  รหัสสินค้า  \
# 0       S002-RTB   NonMember     1/1/2023  S002230101000119392     1145528
# 1       S002-RTB   NonMember     1/1/2023  S002230101005039881     1118291
# 2       S002-RTB   NonMember     1/1/2023  S002230101005039881     1077454
# 3       S002-RTB   NonMember     1/1/2023  S002230101005039881      291538
# 4       S002-RTB   NonMember     1/1/2023  S002230101005039881     1119482
# ...          ...         ...          ...                  ...         ...
# 228550  S020-HYI   NonMember   26/11/2022  S020221126005145272     1160172
# 228551  S020-HYI  1004771131   26/12/2022  S020221226003051813      241545
# 228552  S020-HYI  1004771131   26/11/2022  S020221126005145145     1144580
# 228553  S020-HYI  1004771131   26/11/2022  S020221126005145145     1084136
# 228554  S020-HYI  1004771131   27/11/2022  S020221127005145372     1104248
#
# ...

# %%
data_x.isnull().any()
# Out:
# Store                         False
# Member No.                    False
# Billing Date                  False
# Ticket Number                 False
# รหัสสินค้า                    False
# ชื่อสินค้า_x                  False
# Billing Quantity.Base Unit    False
# Billing Amount (+VAT)         False
# ชื่อสินค้า_y                   True
# Base Unit                      True
# กลุ่มสินค้าหลัก                True
# ชื่อกลุ่มสินค้า                True
# กลุ่มสินค้า1                   True
# กลุ่มสินค้า1_Desc              True
# กลุ่มสินค้า2                   True
# กลุ่มสินค้า2_Desc              True
# กลุ่มสินค้า3                   True
# กลุ่มสินค้า3_Desc              True
# Vendor                         True
# Vendor_Name                    True
# Brand                          True
# Site                          False
# Site_Desc                     False
# TH_NAME                       False
# เขตรับผิดชอบ                  False
# Region                        False
# ...

# %%
data_x = data_x.dropna()
data_x
# Out:
#            Store  Member No. Billing Date        Ticket Number  รหัสสินค้า  \
# 0       S002-RTB   NonMember     1/1/2023  S002230101000119392     1145528
# 1       S002-RTB   NonMember     1/1/2023  S002230101005039881     1118291
# 2       S002-RTB   NonMember     1/1/2023  S002230101005039881     1077454
# 3       S002-RTB   NonMember     1/1/2023  S002230101005039881      291538
# 4       S002-RTB   NonMember     1/1/2023  S002230101005039881     1119482
# ...          ...         ...          ...                  ...         ...
# 228550  S020-HYI   NonMember   26/11/2022  S020221126005145272     1160172
# 228551  S020-HYI  1004771131   26/12/2022  S020221226003051813      241545
# 228552  S020-HYI  1004771131   26/11/2022  S020221126005145145     1144580
# 228553  S020-HYI  1004771131   26/11/2022  S020221126005145145     1084136
# 228554  S020-HYI  1004771131   27/11/2022  S020221127005145372     1104248
#
# ...

# %%
before = 228555
after = 228549
print(f'before = {before} \nafter = {after}\nwhich is {100*((before-after)/before)}')
# Out:
# before = 228555
# after = 228549
# which is 0.0026251886854367656

# %%
total = data_x[['Store','ชื่อสินค้า_x','Billing Quantity.Base Unit','Billing Amount (+VAT)','ชื่อกลุ่มสินค้า','กลุ่มสินค้า1_Desc','กลุ่มสินค้า2_Desc','กลุ่มสินค้า3_Desc','Vendor_Name','Brand','Province']]
total
# Out:
#            Store                             ชื่อสินค้า_x  \
# 0       S002-RTB  ก/บพื้น 16X16 เวียงก้า น้ำตาล PM 0.96M2
# 1       S002-RTB               ฝักบัวสายอ่อน KS-39-231-50
# 2       S002-RTB        เตาแก๊สตั้งโต๊ะ 2G MR MEX PC727CB
# 3       S002-RTB             หัวปรับความดันต่ำ MEX SPR37S
# 4       S002-RTB    สายยางแก๊สอย่างหนา PAR KNITTING 1.5 M
# ...          ...                                      ...
# 228550  S020-HYI    แคปซูล ค.ชงกาแฟ NESTLE Americano int5
# 228551  S020-HYI           กระติกน้ำร้อนM SHA KP30ST 2.9L
# 228552  S020-HYI      ค.ซักผ้า2T LG TT13WARG.DLGPETH 13KG
# 228553  S020-HYI   ค.ฉีดน้ำ BOSCH AQUATAK125 125BAR 1500W
# 228554  S020-HYI           หม้อต้มน้ำไฟฟ้า MIZ KT-119 20L
#
#         Billing Quantity.Base Unit  Billing Amount (+VAT)  \
# 0                             -7.0               -1215.41
# 1                              1.0                 519.00
# 2                              1.0                2890.00
# ...

# %%
total.isnull().any()
# Out:
# Store                         False
# ชื่อสินค้า_x                  False
# Billing Quantity.Base Unit    False
# Billing Amount (+VAT)         False
# ชื่อกลุ่มสินค้า               False
# กลุ่มสินค้า1_Desc             False
# กลุ่มสินค้า2_Desc             False
# กลุ่มสินค้า3_Desc             False
# Vendor_Name                   False
# Brand                         False
# Province                      False
# dtype: bool

# %%
total.to_csv('finish', encoding = 'utf-8')
