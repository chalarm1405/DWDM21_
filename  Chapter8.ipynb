# %% [markdown]
# <a href="https://colab.research.google.com/github/chalarm1405/DWDM21_/blob/main/%20Chapter8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2021-10-19 002224.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2021-10-19 002317.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2021-10-19 002351.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# จากรูปภาพแผนภูมิต้นไม้รากของต้นไม้จะอยู่ด้านบนเสมอและใบจะอยู่ด้านล่าง

# %% [markdown]
# ![4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #สูตรที่ใช้ในการคำนวณ

# %% [markdown]
# ![Screenshot 2021-10-19 002422.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2021-10-19 002451.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2021-10-19 003457.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2021-10-19 003508.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![9.jpg](data:image/jpeg;base64,...)
